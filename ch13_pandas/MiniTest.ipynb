# %%
a = 50

# %%
b = 20

# %%
c = a + b
print(c)
# Out:
# 70

# %%
for idx in range(1, 6):
    print(idx)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# <h1><font color = "blue">쥬피터 노트북 연습</font></h1>

# %% [markdown]
# <h3><font color = "red">중분류</font></h3>

# %% [markdown]
# <h6><font color = "BlueViolet">파이썬 제어문 공부</font></h6>
