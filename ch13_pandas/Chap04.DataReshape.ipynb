# %%
import pandas as pd

# %%
dataIn = './../dataIn/'
dataOut = './../dataOut/'

# %%
filename01 = dataIn + '가전제품판매량01.csv'
homeware01 = pd.read_csv(filename01, encoding= 'CP949', index_col= '지역')
homeware01

# %%
filename02 = dataIn + '가전제품판매량02.csv'
homeware02 = pd.read_csv(filename02, encoding= 'CP949', index_col= '지역')
homeware02

# %%
columnInfo01 = homeware01.columns # 상반기 컬럼 정보
columnInfo02 = homeware02.columns # 하반기 컬럼 정보

# %%
print('양쪽에 공통적으로 들어가 있는 제품')
columnInfo01.intersection(columnInfo02)

# %%
print('상반기에만 판매된 제품')
print(columnInfo01.difference(columnInfo02))
print('\n하반기에만 판매된 제품')
print(columnInfo02.difference(columnInfo01))

# %%
print('분기별 판매량 결합')
result = pd.concat([homeware01, homeware02], join= 'inner')
result

# %%
print('양쪽에 공통적이지 않은 항목은 NaN 데이터가 됩니다.')
result = pd.concat([homeware01, homeware02], axis=0) # outer join
result

# %%
print('열 방향으로 합치기')
result = pd.concat([homeware01, homeware02], axis=1) # outer join
result

# %%
file01 = dataIn + '학생정보01.csv'
student = pd.read_csv(file01, encoding= 'CP949')
student

# %%
file02 = dataIn + '시험점수01.csv'
jumsu = pd.read_csv(file02, encoding = 'CP949')
jumsu

# %%
print('양쪽 프레임에 공통된 컬럼 정보')
col_student = student.columns
col_jumsu = jumsu.columns
col_student.intersection(col_jumsu)

# %%
result = pd.merge(student, jumsu, on= 'id')
result

# %%
chartdata03 = result.copy()
chartdata03 = chartdata03.loc[chartdata03['id'] == 'kang',['과목','점수']]
chartdata03 = chartdata03.set_index('과목')
chartdata03

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %%
chartdata03.plot(kind='pie', y = '점수', autopct='%1.1f%%')
plt.xlabel(chartdata03.index.name)
plt.title(f'과목별 점수 비율')

# %%
result = pd.merge(student, jumsu, on= 'id', how = 'outer')
result

# %%
result = pd.merge(student, jumsu, on= 'id', how = 'left')
result

# %%
result = pd.merge(student, jumsu, on= 'id', how = 'right')
result

# %%
file01 = dataIn + '학생정보02.csv'
student = pd.read_csv(file01, encoding='CP949')
student

# %%
file02 = dataIn + '시험점수02.csv'
jumsu = pd.read_csv(file02, encoding='CP949')
jumsu

# %%
result = pd.merge(student, jumsu, left_on='leftid', right_on='rightid')
result

# %%
file01 = dataIn + '시험점수03.csv'
data01 = pd.read_csv(file01, encoding='CP949')
data01

# %%
file02 = dataIn + '시험점수04.csv'
data02 = pd.read_csv(file02, encoding='CP949')
data02

# %%
on_condition = ['이름', '과목']
result = pd.merge(data01, data02, on = on_condition, how='outer')
result

# %%
file01 = dataIn + '시험점수05.csv'
data01 = pd.read_csv(file01, encoding='CP949')
data01
# Out:
#     이름  과목  시험
# 0  강호섭  국어  10
# 1  강호섭  영어  15
# 2  강호섭  수학  20
# 3  윤진혁  국어  25
# 4  윤진혁  영어  30
# 5  윤진혁  수학  30

# %%
file02 = dataIn + '시험점수06.csv'
data02 = pd.read_csv(file02, encoding='CP949')
data02
# Out:
#     이름  과목  시험
# 0  강호섭  국어  15
# 1  강호섭  영어  25
# 2  강호섭  수학  35
# 3  윤진혁  국어  45
# 4  윤진혁  영어  55

# %%
print('동일한 이름의 컬럼이 있는 경우, 접미사로 구분합니다.')
on_condition = ['이름', '과목']
result = pd.merge(data01, data02, on = on_condition, how='outer', suffixes=('_중간','_기말'))
result
# Out:
# 동일한 이름의 컬럼이 있는 경우, 접미사로 구분합니다.
#     이름  과목  시험_중간  시험_기말
# 0  강호섭  국어     10   15.0
# 1  강호섭  수학     20   35.0
# 2  강호섭  영어     15   25.0
# 3  윤진혁  국어     25   45.0
# 4  윤진혁  수학     30    NaN
# 5  윤진혁  영어     30   55.0

# %%
filename = dataIn + 'pivotFile.csv'
data = pd.read_csv(filename, encoding='UTF-8')
data
# Out:
#    name    item  value  qty
# 0   kim   apple    100   10
# 1   kim  orange    200   20
# 2   kim   peach    300   30
# 3  park   apple    100   40
# 4  park  orange    500   50
# 5  park   peach    600   60

# %%
pivotData = data.pivot(index= 'name', columns='item', values=['value','qty'])
pivotData
# Out:
#      value                qty
# item apple orange peach apple orange peach
# name
# kim    100    200   300    10     20    30
# park   100    500   600    40     50    60

# %%
print('직원별 실적')
filename = dataIn + 'meltsheet.csv'
siljuk = pd.read_csv(filename, encoding='CP949')
siljuk
# Out:
# 직원별 실적
#     이름  1월  2월  3월  4월  5월  6월  7월  8월  9월  10월  11월  12월
# 0  강감찬  59  92  66  98  59  70  77  67  88   61   57   52
# 1  홍길동  90  96  56  92  95  54  80  62  64   65   90   73
# 2  이순신  65  70  74  60  57  76  61  53  79   95   61   75
# 3  김유신  93  67  90  82  98  61  80  95  83   80   88   86

# %%
chartdata = siljuk.copy()
chartdata = chartdata.set_index('이름').T
chartdata
# Out:
# 이름   강감찬  홍길동  이순신  김유신
# 1월    59   90   65   93
# 2월    92   96   70   67
# 3월    66   56   74   90
# 4월    98   92   60   82
# 5월    59   95   57   98
# 6월    70   54   76   61
# 7월    77   80   61   80
# 8월    67   62   53   95
# 9월    88   64   79   83
# 10월   61   65   95   80
# 11월   57   90   61   88
# 12월   52   73   75   86

# %%
chartdata.plot(kind='bar',figsize=(10,6), ylim=(50, 100), rot=10)
plt.xlabel('월')
plt.ylabel('실적')
plt.title('직원별 월별 실적')
# Out:
# Text(0.5, 1.0, '직원별 월별 실적')

# %%
siljuk_long = pd.melt(siljuk, id_vars=['이름'],var_name='월',value_name='실적')
siljuk_long
# Out:
#      이름    월  실적
# 0   강감찬   1월  59
# 1   홍길동   1월  90
# 2   이순신   1월  65
# 3   김유신   1월  93
# 4   강감찬   2월  92
# 5   홍길동   2월  96
# 6   이순신   2월  70
# 7   김유신   2월  67
# 8   강감찬   3월  66
# 9   홍길동   3월  56
# 10  이순신   3월  74
# 11  김유신   3월  90
# 12  강감찬   4월  98
# 13  홍길동   4월  92
# 14  이순신   4월  60
# 15  김유신   4월  82
# 16  강감찬   5월  59
# 17  홍길동   5월  95
# 18  이순신   5월  57
# 19  김유신   5월  98
# 20  강감찬   6월  70
# 21  홍길동   6월  54
# 22  이순신   6월  76
# 23  김유신   6월  61
# 24  강감찬   7월  77
# 25  홍길동   7월  80
# 26  이순신   7월  61
# 27  김유신   7월  80
# 28  강감찬   8월  67
# 29  홍길동   8월  62
# 30  이순신   8월  53
# 31  김유신   8월  95
# 32  강감찬   9월  88
# 33  홍길동   9월  64
# 34  이순신   9월  79
# 35  김유신   9월  83
# 36  강감찬  10월  61
# 37  홍길동  10월  65
# 38  이순신  10월  95
# 39  김유신  10월  80
# 40  강감찬  11월  57
# 41  홍길동  11월  90
# 42  이순신  11월  61
# 43  김유신  11월  88
# 44  강감찬  12월  52
# 45  홍길동  12월  73
# 46  이순신  12월  75
# 47  김유신  12월  86

# %%
filename = dataIn + 'movie_show.csv'
movieshow = pd.read_csv(filename, encoding='CP949')
movieshow
# Out:
#     gu  year  month  드라마  공포  액션
# 0  마포구  2020      1   10  20  10
# 1  용산구  2020      1   20  20  30
# 2  마포구  2020      2   30  10  10
# 3  용산구  2020      2   30  30  20
# 4  마포구  2020      3   10  20  10
# 5  용산구  2020      3   20  20  30

# %%
movieshow_melt = pd.melt(movieshow, id_vars=['gu','year','month'],var_name='genre',value_name='qty')
movieshow_melt
# Out:
#      gu  year  month genre  qty
# 0   마포구  2020      1   드라마   10
# 1   용산구  2020      1   드라마   20
# 2   마포구  2020      2   드라마   30
# 3   용산구  2020      2   드라마   30
# 4   마포구  2020      3   드라마   10
# 5   용산구  2020      3   드라마   20
# 6   마포구  2020      1    공포   20
# 7   용산구  2020      1    공포   20
# 8   마포구  2020      2    공포   10
# 9   용산구  2020      2    공포   30
# 10  마포구  2020      3    공포   20
# 11  용산구  2020      3    공포   20
# 12  마포구  2020      1    액션   10
# 13  용산구  2020      1    액션   30
# 14  마포구  2020      2    액션   10
# 15  용산구  2020      2    액션   20
# 16  마포구  2020      3    액션   10
# 17  용산구  2020      3    액션   30

# %%
# aggfunc 매개 변수(집계 함수)의 기본 값은 평균(mean) 입니다.
movieshow_pivot = movieshow_melt.pivot_table(index=['gu','year'],columns='month',values='qty', aggfunc= 'sum')
movieshow_pivot
# Out:
# month      1   2   3
# gu  year
# 마포구 2020  40  50  40
# 용산구 2020  70  80  70

# %%
dict_aggfunc = {'genre':'count','qty':'mean'}

movieshow_pivot = movieshow_melt.pivot_table(
    index=['gu','year'],
    columns='month',
    values=['genre','qty'],
    aggfunc=dict_aggfunc
)
movieshow_pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 3
#       1 dict_aggfunc = {'genre':'count','qty':'mean'}
# ----> 3 movieshow_pivot = movieshow_melt.pivot_table(
#       4     index=['gu','year'],
#       5     columns='month',
#       6     values= 'qty',
#       7     aggfunc=dict_aggfunc
#       8 )
#       9 movieshow_pivot
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:9536, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9519 @Substitution("")
#    9520 @Appender(_shared_docs["pivot_table"])
#    9521 def pivot_table(
#    (...)   9532     sort: bool = True,
#    9533 ) -> DataFrame:
#    9534     from pandas.core.reshape.pivot import pivot_table
# -> 9536     return pivot_table(
#    9537         self,
#    9538         values=values,
#    9539         index=index,
#    9540         columns=columns,
#    9541         aggfunc=aggfunc,
#    9542         fill_value=fill_value,
#    9543         margins=margins,
#    9544         dropna=dropna,
#    9545         margins_name=margins_name,
#    9546         observed=observed,
#    9547         sort=sort,
#    9548     )
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:183, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)    181         stacklevel=find_stack_level(),
#     182     )
# --> 183 agged = grouped.agg(aggfunc)
#     185 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     186     agged = agged.dropna(how="all")
#
# File C:\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File C:\Python311\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File C:\Python311\Lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)    421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File C:\Python311\Lib\site-packages\pandas\core\apply.py:1603, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1598     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1600 with com.temp_setattr(
#    1601     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1602 ):
# -> 1603     result_index, result_data = self.compute_dict_like(
#    1604         op_name, selected_obj, selection, kwargs
#    1605     )
#    1606 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1607 return result
#
# File C:\Python311\Lib\site-packages\pandas\core\apply.py:462, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     460 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     461 func = cast(AggFuncTypeDict, self.func)
# --> 462 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     464 is_non_unique_col = (
#     465     selected_obj.ndim == 2
#     466     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     467 )
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#
# File C:\Python311\Lib\site-packages\pandas\core\apply.py:663, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     661     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     662     if len(cols) > 0:
# --> 663         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     665 aggregator_types = (list, tuple, dict)
#     667 # if we have a dict of any non-scalars
#     668 # eg. {'A' : ['mean']}, normalize all to
#     669 # be list-likes
#     670 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['genre'] do not exist"

# %%
# 특정 컬럼에 대하여 여러 개의 함수 지정이 가능합니다.
dict_aggfunc = {'qty': ['mean','sum']}

movieshow_pivot = movieshow_melt.pivot_table(
    index=['gu', 'year'],
    columns='genre',
    values='qty',
    aggfunc=dict_aggfunc
)
movieshow_pivot
# Out:
#                mean                       sum
# genre            공포        드라마         액션  공포 드라마  액션
# gu  year
# 마포구 2020  16.666667  16.666667  10.000000  50  50  30
# 용산구 2020  23.333333  23.333333  26.666667  70  70  80

# %%
# 내부와 외부 색인을 합쳐서 간단하게 만들기
outer = movieshow_pivot.columns.get_level_values(0) # 외부 색인
inner = movieshow_pivot.columns.get_level_values(1) # 내부 색인
hangul_dict = {'mean': '평균', 'sum' : '총합', 'max' : '최대'}
newOuter = [hangul_dict[asdf] for asdf in outer]
newColumns = inner + '_' + newOuter
movieshow_pivot.columns = newColumns
movieshow_pivot
# Out:
# genre         공포_평균     드라마_평균      액션_평균  공포_총합  드라마_총합  액션_총합
# gu  year
# 마포구 2020  16.666667  16.666667  10.000000     50      50     30
# 용산구 2020  23.333333  23.333333  26.666667     70      70     80
